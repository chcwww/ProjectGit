# %%
# Project

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

offers = pd.read_csv(r'/content/drive/MyDrive/1經濟學/專題/offers.csv')
#transactions = pd.read_csv(r'/content/drive/MyDrive/1經濟學/專題/newdata.csv')
trainHistory = pd.read_csv(r'/content/drive/MyDrive/1經濟學/專題/trainHistory.csv')
testHistory = pd.read_csv(r'/content/drive/MyDrive/1經濟學/專題/testHistory.csv')

tranDtype = {'id': 'uint64',
 'chain': 'uint16',
 'dept': 'uint8',
 'category': 'uint16',
 'company': 'uint64',
 'brand': 'uint32',
#  'date' : 'object',
 'productsize': 'float32',
 'productmeasure': 'category',
 'purchasequantity': 'int64',
 'purchaseamount': 'float32'}
# Out:
# Mounted at /content/drive

# %%
def generateFeature(offers, transactions, trainHistory, testHistory, tidx) :
  # import useful package
  from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
  from sklearn.preprocessing import StandardScaler
  from datetime import datetime, date
  from datetime import timedelta
  from itertools import cycle
  import pandas as pd
  import numpy as np
  import time
  ts = time.time()
  # tk = 1

  # get all data & delete those not in transactions
  train = trainHistory.drop(columns = ['repeater', 'repeattrips'])
  data = pd.concat([train, testHistory], axis=0, ignore_index=True)
  use = data[data['id'].isin(transactions['id'])] # (310665, )

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(get all data) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  # put offer information into transactions
  of = offers[['offer', 'category', 'company', 'offervalue', 'brand']]
  usf = pd.merge(use, of, on='offer')
  usf.columns = ['id', 'chain', 'offer', 'market', 'offerdate', 'offercategory', 'offercompany',
        'offervalue', 'offerbrand']
  tu = usf[['id', 'offer', 'offerdate', 'offercategory', 'offercompany', 'offerbrand']]
  nu = pd.merge(tu, transactions, on='id')

  del tu, usf, of, transactions

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(put offer information) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  # generate time index
  date_format = '%Y-%m-%d'
  nu['offerdate'] = pd.to_datetime(nu['offerdate'], format = date_format)
  # nu['date'] = pd.to_datetime(nu['date'], format = date_format)
  nu['daydiff'] = nu['offerdate'] - nu['date']
  nu['diff_180'] = nu['offerdate'] - timedelta(days = 180)
  nu['diff_150'] = nu['offerdate'] - timedelta(days = 150)
  nu['diff_120'] = nu['offerdate'] - timedelta(days = 120)
  nu['diff_90'] = nu['offerdate'] - timedelta(days = 90)
  nu['diff_60'] = nu['offerdate'] - timedelta(days = 60)
  nu['diff_30'] = nu['offerdate'] - timedelta(days = 30)

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate time index) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  # put offervalue
  of1 = offers[['offer', 'offervalue']]
  use = pd.merge(use, of1, on='offer')

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(put offervalue) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  # generate total
  group = nu.groupby(['id'])

  test = group['chain'].count().reset_index()
  test.columns = ['id', 'buy_total_freq']
  use = pd.merge(use, test, on='id')

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate total freq) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  test = group['purchaseamount'].sum().reset_index()
  test.columns = ['id', 'buy_total_amount']
  use = pd.merge(use, test, on='id')

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate total amount) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  test = group['purchaseamount'].mean().reset_index()
  test.columns = ['id', 'buy_total_avgamount']
  use = pd.merge(use, test, on='id')

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate total avg) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  test = group['purchasequantity'].sum().reset_index()
  test.columns = ['id', 'buy_total_quantity']
  use = pd.merge(use, test, on='id')

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate total quan) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  test = group['daydiff'].min().reset_index()
  test.columns = ['id', 'buy_total_daydiff']
  use = pd.merge(use, test, on='id')

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate total) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1


  day = np.linspace(30, 180, 6, endpoint=True).astype(int).astype(str)

  for i in day :
    daa = 'diff_' + i
    nu['ascom'] = nu['date'] >= nu[daa]

    name = 'buy_total_amount_' + i
    var = 'purchaseamount'

    group = nu.groupby(['id', 'ascom'])
    test = group[var].sum().reset_index()
    test.columns = ['id', 'ascom', name]
    use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate day amount) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    name = 'buy_total_quantity_' + i
    var = 'purchasequantity'

    group = nu.groupby(['id', 'ascom'])
    test = group[var].sum().reset_index()
    test.columns = ['id', 'ascom', name]
    use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate day quan) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    name = 'buy_total_freq_' + i
    var = 'purchaseamount'

    group = nu.groupby(['id', 'ascom'])
    test = group['chain'].count().reset_index()
    test.columns = ['id', 'ascom', name]
    use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate day) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

  # generate company & brand & category
  mea = ['company', 'brand', 'category']

  for i in mea :
    nu['ascom'] = nu[i] == nu['offer' + i]
    group = nu.groupby(['id', 'ascom'])

    test = group['chain'].count().reset_index()
    test.columns = ['id', 'ascom', 'buy_'+i+'_freq']
    use = pd.merge(use, test[test['ascom']][['id', 'buy_'+i+'_freq']], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other freq) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    test = group['purchaseamount'].sum().reset_index()
    test.columns = ['id', 'ascom', 'buy_'+i+'_amount']
    use = pd.merge(use, test[test['ascom']][['id', 'buy_'+i+'_amount']], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other amount) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    test = group['purchaseamount'].mean().reset_index()
    test.columns = ['id', 'ascom', 'buy_'+i+'_avgamount']
    use = pd.merge(use, test[test['ascom']][['id', 'buy_'+i+'_avgamount']], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other avg) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    test = group['purchasequantity'].sum().reset_index()
    test.columns = ['id', 'ascom', 'buy_'+i+'_quantity']
    use = pd.merge(use, test[test['ascom']][['id', 'buy_'+i+'_quantity']], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other quan) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    test = group['daydiff'].min().reset_index()
    test.columns = ['id', 'ascom', 'buy_'+i+'_daydiff']
    use = pd.merge(use, test[test['ascom']][['id', 'buy_'+i+'_daydiff']], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1


  for i, j in zip(day, cycle(mea)) :
    daa = 'diff_' + i
    nu['ascom'] = ((nu['date'] >= nu[daa]) & (nu[j] == nu['offer' + j]))

    name = 'buy_'+j+'_amount_' + i
    var = 'purchaseamount'

    group = nu.groupby(['id', 'ascom'])
    test = group[var].sum().reset_index()
    test.columns = ['id', 'ascom', name]
    use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other day amount) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    name = 'buy_'+j+'_quantity_' + i
    var = 'purchasequantity'

    group = nu.groupby(['id', 'ascom'])
    test = group[var].sum().reset_index()
    test.columns = ['id', 'ascom', name]
    use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')

    # te = time.time()
    # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other day quan) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # tk+=1

    name = 'buy_'+j+'_freq_' + i
    var = 'purchaseamount'

    group = nu.groupby(['id', 'ascom'])
    test = group['chain'].count().reset_index()
    test.columns = ['id', 'ascom', name]
    use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')

    # te = time.time()
    # # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate other day) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
    # # tk+=1

  # generate not buy index
  nu['ascom'] = (nu['company'] == nu['offercompany']) & (nu['brand'] == nu['offerbrand']) & (nu['category'] == nu['offercategory'])
  group = nu.groupby(['id', 'ascom'])

  name1 = 'buy_company_brand_category'
  name = name1 + '_freq'

  test = group['chain'].count().reset_index()
  test.columns = ['id', 'ascom', name]
  use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')
  use['not_' + name1] = (use[name] > 0) != True

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate not buy) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  nu['ascom'] = (nu['company'] == nu['offercompany']) & (nu['brand'] == nu['offerbrand'])
  group = nu.groupby(['id', 'ascom'])

  name1 = 'buy_company_brand'
  name = name1 + '_freq'

  test = group['chain'].count().reset_index()
  test.columns = ['id', 'ascom', name]
  use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')
  use['not_' + name1] = (use[name] > 0) != True

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate not buy) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  nu['ascom'] = (nu['company'] == nu['offercompany']) & (nu['category'] == nu['offercategory'])
  group = nu.groupby(['id', 'ascom'])

  name1 = 'buy_company_category'
  name = name1 + '_freq'

  test = group['chain'].count().reset_index()
  test.columns = ['id', 'ascom', name]
  use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')
  use['not_' + name1] = (use[name] > 0) != True

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate not buy) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  nu['ascom'] = (nu['brand'] == nu['offerbrand']) & (nu['category'] == nu['offercategory'])
  group = nu.groupby(['id', 'ascom'])

  name1 = 'buy_brand_category'
  name = name1 + '_freq'

  test = group['chain'].count().reset_index()
  test.columns = ['id', 'ascom', name]
  use = pd.merge(use, test[test['ascom']][['id', name]], on='id', how = 'outer')
  use['not_' + name1] = (use[name] > 0) != True

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(generate not buy) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  use['not_buy_company'] = (use['buy_company_freq'] > 0) != True
  use['not_buy_brand'] = (use['buy_brand_freq'] > 0) != True
  use['not_buy_category'] = (use['buy_category_freq'] > 0) != True

  # handle na problem
  dayVar = ['buy_company_daydiff', 'buy_brand_daydiff', 'buy_category_daydiff', 'buy_total_daydiff']
  use1 = use[dayVar]
  use.drop(columns = dayVar, inplace = True)
  use = use.fillna(0)
  use1 = use1.fillna(timedelta(0))
  use[dayVar] = use1

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(handle na problem) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  # transform date type into int
  for i in use.columns[range(69, 73)] :
    use[i] = use[i].astype('str').apply(lambda x:x[:-5]).astype('int32')

  # te = time.time()
  # print('Inner -', str(tidx) + ' of ' + str(tk) + '(transform date type) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  # tk+=1

  # transform bool type into int
  for i in use.columns :
    if(use[i].dtypes == 'bool') :
      use[i] = use[i].apply(int)

  te = time.time()
  print('Inner -', str(tidx) + ' (generate feature) -> time elapsed: ' + str(round(te-ts, 2)) + ' seconds')
  
  return use

# %%
def find_index(data_col, val):
    val_list = []
    
    val_list.append(val)
    val_list.append("end")

    index = data_col.isin(val_list).idxmax()
    
    return index

# %% [markdown]
# Start Generate

# %%
import time
t1 = time.time()

to = 1
idx = 1

while(to <= 30) :
  tm = 1

  t2 = time.time()
  print('\nStage -', str(to) + ' of ' + str(tm) + '(start) -> time elapsed: ' + str(round(t2-t1, 2)) + ' seconds')
  tm+=1

  # from dask import dataframe as dd
  transactions = pd.read_csv('/content/drive/MyDrive/1經濟學/專題/transactions.csv', 
      names=['id', 'chain', 'dept', 'category', 'company', 'brand', 'date', \
             'productsize', 'productmeasure', 'purchasequantity', 'purchaseamount'],
      dtype = tranDtype,
      nrows = 10000000,
      parse_dates=['date'],
      infer_datetime_format=True,
      header = idx
      # blocksize=64000000 # = 64 Mb chunks
  )

  idx1 = find_index(transactions['id'], int(transactions['id'].loc[len(transactions['id']) - 1]))

  del transactions

  t2 = time.time()
  print('Stage -', str(to) + ' of ' + str(tm) + '(read data) -> time elapsed: ' + str(round(t2-t1, 2)) + ' seconds')
  tm+=1

  transactions = pd.read_csv('/content/drive/MyDrive/1經濟學/專題/transactions.csv', 
      names=['id', 'chain', 'dept', 'category', 'company', 'brand', 'date', \
             'productsize', 'productmeasure', 'purchasequantity', 'purchaseamount'],
      dtype = tranDtype,
      nrows = idx1,
      parse_dates=['date'],
      infer_datetime_format=True,
      header = idx
      # blocksize=64000000 # = 64 Mb chunks
  )

  t2 = time.time()
  print('Stage -', str(to) + ' of ' + str(tm) + '(reRead data) -> time elapsed: ' + str(round(t2-t1, 2)) + ' seconds' \
        + '\n\nStart : ' + str(idx) + ' End : ' + str(idx+idx1-1) + '\n')
  tm+=1

  idx += idx1
    
  use = generateFeature(offers, transactions, trainHistory, testHistory, to)

  t2 = time.time()
  print('Stage -', str(to) + ' of ' + str(tm) + '(generate) -> time elapsed: ' + str(round(t2-t1, 2)) + ' seconds')
  tm+=1

  dic = '/content/drive/MyDrive/1經濟學/專題/split/targetSplit' + str(to) + '.csv'

  use.to_csv(dic)

  del use

  t2 = time.time()
  print('Stage -', str(to) + ' of ' + str(tm) + '(ouput) -> time elapsed: ' + str(round(t2-t1, 2)) + ' seconds\n')
  tm+=1
  to+=1
# Out:
# Stage - 1 of 1(start) -> time elapsed: 0.0 seconds
# Stage - 1 of 2(read data) -> time elapsed: 10.77 seconds
# Stage - 1 of 3(reRead data) -> time elapsed: 22.09 seconds
#
# Start : 1 End : 9998979
#
# Inner - 1 of 1(get all data) -> time elapsed: 0.23 seconds
# Inner - 1 of 2(put offer information) -> time elapsed: 4.69 seconds
# Inner - 1 of 3(generate time index) -> time elapsed: 12.03 seconds
# Inner - 1 of 4(put offervalue) -> time elapsed: 12.03 seconds
# Inner - 1 of 5(generate total) -> time elapsed: 12.73 seconds
# Inner - 1 of 6(generate day) -> time elapsed: 14.81 seconds
# Inner - 1 of 7(generate day) -> time elapsed: 16.69 seconds
# Inner - 1 of 8(generate day) -> time elapsed: 18.56 seconds
# Inner - 1 of 9(generate day) -> time elapsed: 20.42 seconds
# Inner - 1 of 10(generate day) -> time elapsed: 22.32 seconds
# Inner - 1 of 11(generate day) -> time elapsed: 24.27 seconds
# Inner - 1 of 12(generate other) -> time elapsed: 25.31 seconds
# Inner - 1 of 13(generate other) -> time elapsed: 26.33 seconds
# Inner - 1 of 14(generate other) -> time elapsed: 27.37 seconds
# Inner - 1 of 15(generate other day) -> time elapsed: 29.3 seconds
# Inner - 1 of 16(generate other day) -> time elapsed: 31.21 seconds
# Inner - 1 of 17(generate other day) -> time elapsed: 33.12 seconds
# Inner - 1 of 18(generate other day) -> time elapsed: 35.1 seconds
# Inner - 1 of 19(generate other day) -> time elapsed: 37.05 seconds
# Inner - 1 of 20(generate other day) -> time elapsed: 38.96 seconds
# Inner - 1 of 21(generate not buy) -> time elapsed: 41.46 seconds
# Inner - 1 of 22(handle na problem) -> time elapsed: 41.47 seconds
# Inner - 1 of 23(transform date type) -> time elapsed: 41.75 seconds
# Inner - 1 of 24(transform bool type) -> time elapsed: 41.77 seconds
# Stage - 1 of 4(generate) -> time elapsed: 63.89 seconds
# Stage - 1 of 5(ouput) -> time elapsed: 64.3 seconds
#
# Stage - 2 of 1(start) -> time elapsed: 64.3 seconds
# Stage - 2 of 2(read data) -> time elapsed: 159.99 seconds
# Stage - 2 of 3(reRead data) -> time elapsed: 251.04 seconds
#
# Start : 9998980 End : 19997375
#
# Inner - 2 of 1(get all data) -> time elapsed: 0.16 seconds
# Inner - 2 of 2(put offer information) -> time elapsed: 2.92 seconds
# Inner - 2 of 3(generate time index) -> time elapsed: 4.81 seconds
# Inner - 2 of 4(put offervalue) -> time elapsed: 4.81 seconds
# Inner - 2 of 5(generate total) -> time elapsed: 5.39 seconds
# Inner - 2 of 6(generate day) -> time elapsed: 7.31 seconds
# Inner - 2 of 7(generate day) -> time elapsed: 9.22 seconds
# Inner - 2 of 8(generate day) -> time elapsed: 11.1 seconds
# Inner - 2 of 9(generate day) -> time elapsed: 12.96 seconds
# Inner - 2 of 10(generate day) -> time elapsed: 14.84 seconds
# Inner - 2 of 11(generate day) -> time elapsed: 16.71 seconds
# Inner - 2 of 12(generate other) -> time elapsed: 17.74 seconds
# Inner - 2 of 13(generate other) -> time elapsed: 18.77 seconds
# Inner - 2 of 14(generate other) -> time elapsed: 19.84 seconds
# Inner - 2 of 15(generate other day) -> time elapsed: 21.82 seconds
# Inner - 2 of 16(generate other day) -> time elapsed: 23.73 seconds
# Inner - 2 of 17(generate other day) -> time elapsed: 25.63 seconds
# Inner - 2 of 18(generate other day) -> time elapsed: 27.55 seconds
# Inner - 2 of 19(generate other day) -> time elapsed: 29.47 seconds
# Inner - 2 of 20(generate other day) -> time elapsed: 31.39 seconds
# Inner - 2 of 21(generate not buy) -> time elapsed: 34.01 seconds
# Inner - 2 of 22(handle na problem) -> time elapsed: 34.03 seconds
# Inner - 2 of 23(transform date type) -> time elapsed: 34.32 seconds
# Inner - 2 of 24(transform bool type) -> time elapsed: 34.34 seconds
# Stage - 2 of 4(generate) -> time elapsed: 285.39 seconds
# Stage - 2 of 5(ouput) -> time elapsed: 285.81 seconds
#
# Stage - 3 of 1(start) -> time elapsed: 285.81 seconds
# Stage - 3 of 2(read data) -> time elapsed: 463.92 seconds
# Stage - 3 of 3(reRead data) -> time elapsed: 635.34 seconds
#
# Start : 19997376 End : 29996608
#
# Inner - 3 of 1(get all data) -> time elapsed: 0.16 seconds
# Inner - 3 of 2(put offer information) -> time elapsed: 5.33 seconds
# Inner - 3 of 3(generate time index) -> time elapsed: 8.79 seconds
# Inner - 3 of 4(put offervalue) -> time elapsed: 8.8 seconds
# Inner - 3 of 5(generate total) -> time elapsed: 9.77 seconds
# Inner - 3 of 6(generate day) -> time elapsed: 12.79 seconds
# Inner - 3 of 7(generate day) -> time elapsed: 14.96 seconds
# Inner - 3 of 8(generate day) -> time elapsed: 17.18 seconds
# Inner - 3 of 9(generate day) -> time elapsed: 19.14 seconds
# Inner - 3 of 10(generate day) -> time elapsed: 20.83 seconds
# Inner - 3 of 11(generate day) -> time elapsed: 22.52 seconds
# Inner - 3 of 12(generate other) -> time elapsed: 23.43 seconds
# Inner - 3 of 13(generate other) -> time elapsed: 24.38 seconds
# Inner - 3 of 14(generate other) -> time elapsed: 25.29 seconds
# Inner - 3 of 15(generate other day) -> time elapsed: 26.99 seconds
# Inner - 3 of 16(generate other day) -> time elapsed: 28.68 seconds
# Inner - 3 of 17(generate other day) -> time elapsed: 30.39 seconds
# Inner - 3 of 18(generate other day) -> time elapsed: 32.18 seconds
# Inner - 3 of 19(generate other day) -> time elapsed: 33.92 seconds
# Inner - 3 of 20(generate other day) -> time elapsed: 35.62 seconds
# Inner - 3 of 21(generate not buy) -> time elapsed: 37.87 seconds
# Inner - 3 of 22(handle na problem) -> time elapsed: 37.88 seconds
# Inner - 3 of 23(transform date type) -> time elapsed: 37.97 seconds
# Inner - 3 of 24(transform bool type) -> time elapsed: 37.98 seconds
# Stage - 3 of 4(generate) -> time elapsed: 673.33 seconds
# Stage - 3 of 5(ouput) -> time elapsed: 673.47 seconds
#
# Stage - 4 of 1(start) -> time elapsed: 673.47 seconds
# Stage - 4 of 2(read data) -> time elapsed: 938.06 seconds
# Stage - 4 of 3(reRead data) -> time elapsed: 1190.9 seconds
#
# Start : 29996609 End : 39995439
#
# Inner - 4 of 1(get all data) -> time elapsed: 0.15 seconds
# Inner - 4 of 2(put offer information) -> time elapsed: 3.05 seconds
# Inner - 4 of 3(generate time index) -> time elapsed: 5.12 seconds
# Inner - 4 of 4(put offervalue) -> time elapsed: 5.12 seconds
# Inner - 4 of 5(generate total) -> time elapsed: 5.72 seconds
# Inner - 4 of 6(generate day) -> time elapsed: 7.71 seconds
# Inner - 4 of 7(generate day) -> time elapsed: 9.58 seconds
# Inner - 4 of 8(generate day) -> time elapsed: 11.51 seconds
# Inner - 4 of 9(generate day) -> time elapsed: 13.4 seconds
# Inner - 4 of 10(generate day) -> time elapsed: 15.28 seconds
# Inner - 4 of 11(generate day) -> time elapsed: 17.23 seconds
# Inner - 4 of 12(generate other) -> time elapsed: 18.29 seconds
# Inner - 4 of 13(generate other) -> time elapsed: 19.34 seconds
# Inner - 4 of 14(generate other) -> time elapsed: 20.4 seconds
# Inner - 4 of 15(generate other day) -> time elapsed: 22.34 seconds
# Inner - 4 of 16(generate other day) -> time elapsed: 24.31 seconds
# Inner - 4 of 17(generate other day) -> time elapsed: 26.23 seconds
# Inner - 4 of 18(generate other day) -> time elapsed: 28.16 seconds
# Inner - 4 of 19(generate other day) -> time elapsed: 30.14 seconds
# Inner - 4 of 20(generate other day) -> time elapsed: 32.13 seconds
# Inner - 4 of 21(generate not buy) -> time elapsed: 34.73 seconds
# Inner - 4 of 22(handle na problem) -> time elapsed: 34.74 seconds
# Inner - 4 of 23(transform date type) -> time elapsed: 34.97 seconds
# Inner - 4 of 24(transform bool type) -> time elapsed: 34.99 seconds
# Stage - 4 of 4(generate) -> time elapsed: 1225.91 seconds
# Stage - 4 of 5(ouput) -> time elapsed: 1226.24 seconds
#
# Stage - 5 of 1(start) -> time elapsed: 1226.24 seconds
# Stage - 5 of 2(read data) -> time elapsed: 1569.33 seconds
# Stage - 5 of 3(reRead data) -> time elapsed: 1903.45 seconds
#
# Start : 39995440 End : 49995222
#
# Inner - 5 of 1(get all data) -> time elapsed: 0.15 seconds
# Inner - 5 of 2(put offer information) -> time elapsed: 3.0 seconds
# Inner - 5 of 3(generate time index) -> time elapsed: 5.06 seconds
# Inner - 5 of 4(put offervalue) -> time elapsed: 5.06 seconds
# Inner - 5 of 5(generate total) -> time elapsed: 5.64 seconds
# Inner - 5 of 6(generate day) -> time elapsed: 7.62 seconds
# Inner - 5 of 7(generate day) -> time elapsed: 9.51 seconds
# Inner - 5 of 8(generate day) -> time elapsed: 11.39 seconds
# Inner - 5 of 9(generate day) -> time elapsed: 13.28 seconds
# Inner - 5 of 10(generate day) -> time elapsed: 15.17 seconds
# Inner - 5 of 11(generate day) -> time elapsed: 17.05 seconds
# Inner - 5 of 12(generate other) -> time elapsed: 18.09 seconds
# Inner - 5 of 13(generate other) -> time elapsed: 19.14 seconds
# Inner - 5 of 14(generate other) -> time elapsed: 20.21 seconds
# Inner - 5 of 15(generate other day) -> time elapsed: 22.15 seconds
# Inner - 5 of 16(generate other day) -> time elapsed: 24.07 seconds
# Inner - 5 of 17(generate other day) -> time elapsed: 25.99 seconds
# Inner - 5 of 18(generate other day) -> time elapsed: 27.93 seconds
# Inner - 5 of 19(generate other day) -> time elapsed: 29.86 seconds
# Inner - 5 of 20(generate other day) -> time elapsed: 31.84 seconds
# Inner - 5 of 21(generate not buy) -> time elapsed: 34.37 seconds
# Inner - 5 of 22(handle na problem) -> time elapsed: 34.39 seconds
# Inner - 5 of 23(transform date type) -> time elapsed: 34.58 seconds
# Inner - 5 of 24(transform bool type) -> time elapsed: 34.6 seconds
# Stage - 5 of 4(generate) -> time elapsed: 1938.06 seconds
# Stage - 5 of 5(ouput) -> time elapsed: 1938.32 seconds
#
# Stage - 6 of 1(start) -> time elapsed: 1938.32 seconds
# Stage - 6 of 2(read data) -> time elapsed: 2351.88 seconds
# Stage - 6 of 3(reRead data) -> time elapsed: 2779.88 seconds
#
# Start : 49995223 End : 59994900
#
# Inner - 6 of 1(get all data) -> time elapsed: 0.16 seconds
# Inner - 6 of 2(put offer information) -> time elapsed: 3.47 seconds
# Inner - 6 of 3(generate time index) -> time elapsed: 5.54 seconds
# Inner - 6 of 4(put offervalue) -> time elapsed: 5.55 seconds
# Inner - 6 of 5(generate total) -> time elapsed: 6.12 seconds
# Inner - 6 of 6(generate day) -> time elapsed: 8.02 seconds
# Inner - 6 of 7(generate day) -> time elapsed: 9.9 seconds
# Inner - 6 of 8(generate day) -> time elapsed: 11.77 seconds
# Inner - 6 of 9(generate day) -> time elapsed: 13.68 seconds
# Inner - 6 of 10(generate day) -> time elapsed: 15.6 seconds
# Inner - 6 of 11(generate day) -> time elapsed: 17.48 seconds
# Inner - 6 of 12(generate other) -> time elapsed: 18.52 seconds
# Inner - 6 of 13(generate other) -> time elapsed: 19.56 seconds
# Inner - 6 of 14(generate other) -> time elapsed: 20.61 seconds
# Inner - 6 of 15(generate other day) -> time elapsed: 22.55 seconds
# Inner - 6 of 16(generate other day) -> time elapsed: 24.48 seconds
# Inner - 6 of 17(generate other day) -> time elapsed: 26.46 seconds
# Inner - 6 of 18(generate other day) -> time elapsed: 28.43 seconds
# Inner - 6 of 19(generate other day) -> time elapsed: 30.37 seconds
# Inner - 6 of 20(generate other day) -> time elapsed: 32.3 seconds
# Inner - 6 of 21(generate not buy) -> time elapsed: 34.85 seconds
# Inner - 6 of 22(handle na problem) -> time elapsed: 34.86 seconds
# Inner - 6 of 23(transform date type) -> time elapsed: 35.14 seconds
# Inner - 6 of 24(transform bool type) -> time elapsed: 35.16 seconds
# Stage - 6 of 4(generate) -> time elapsed: 2815.05 seconds
# Stage - 6 of 5(ouput) -> time elapsed: 2815.54 seconds
#
# Stage - 7 of 1(start) -> time elapsed: 2815.54 seconds
# Stage - 7 of 2(read data) -> time elapsed: 3314.07 seconds
# Stage - 7 of 3(reRead data) -> time elapsed: 3826.48 seconds
#
# Start : 59994901 End : 69994368
#
# Inner - 7 of 1(get all data) -> time elapsed: 0.16 seconds
# Inner - 7 of 2(put offer information) -> time elapsed: 3.13 seconds
# Inner - 7 of 3(generate time index) -> time elapsed: 5.26 seconds
# Inner - 7 of 4(put offervalue) -> time elapsed: 5.27 seconds
# Inner - 7 of 5(generate total) -> time elapsed: 5.88 seconds
# Inner - 7 of 6(generate day) -> time elapsed: 7.83 seconds
# Inner - 7 of 7(generate day) -> time elapsed: 9.7 seconds
# Inner - 7 of 8(generate day) -> time elapsed: 11.6 seconds
# Inner - 7 of 9(generate day) -> time elapsed: 13.52 seconds
# Inner - 7 of 10(generate day) -> time elapsed: 15.4 seconds
# Inner - 7 of 11(generate day) -> time elapsed: 17.26 seconds
# Inner - 7 of 12(generate other) -> time elapsed: 18.29 seconds
# Inner - 7 of 13(generate other) -> time elapsed: 19.33 seconds
# Inner - 7 of 14(generate other) -> time elapsed: 20.37 seconds
# Inner - 7 of 15(generate other day) -> time elapsed: 22.32 seconds
# Inner - 7 of 16(generate other day) -> time elapsed: 24.31 seconds
# Inner - 7 of 17(generate other day) -> time elapsed: 26.29 seconds
# Inner - 7 of 18(generate other day) -> time elapsed: 28.24 seconds
# Inner - 7 of 19(generate other day) -> time elapsed: 30.22 seconds
# Inner - 7 of 20(generate other day) -> time elapsed: 32.16 seconds
# Inner - 7 of 21(generate not buy) -> time elapsed: 34.7 seconds
# Inner - 7 of 22(handle na problem) -> time elapsed: 34.71 seconds
# Inner - 7 of 23(transform date type) -> time elapsed: 34.99 seconds
# Inner - 7 of 24(transform bool type) -> time elapsed: 35.01 seconds
# Stage - 7 of 4(generate) -> time elapsed: 3861.5 seconds
# Stage - 7 of 5(ouput) -> time elapsed: 3861.91 seconds
#
# Stage - 8 of 1(start) -> time elapsed: 3861.91 seconds
# Stage - 8 of 2(read data) -> time elapsed: 4444.57 seconds
# Stage - 8 of 3(reRead data) -> time elapsed: 5028.38 seconds
#
# Start : 69994369 End : 79992979
#
# Inner - 8 of 1(get all data) -> time elapsed: 0.16 seconds
# Inner - 8 of 2(put offer information) -> time elapsed: 3.03 seconds
# Inner - 8 of 3(generate time index) -> time elapsed: 5.05 seconds
# Inner - 8 of 4(put offervalue) -> time elapsed: 5.05 seconds
# Inner - 8 of 5(generate total) -> time elapsed: 5.64 seconds
# Inner - 8 of 6(generate day) -> time elapsed: 7.56 seconds
# Inner - 8 of 7(generate day) -> time elapsed: 9.51 seconds
# Inner - 8 of 8(generate day) -> time elapsed: 11.4 seconds
# Inner - 8 of 9(generate day) -> time elapsed: 13.29 seconds
# Inner - 8 of 10(generate day) -> time elapsed: 15.18 seconds
# Inner - 8 of 11(generate day) -> time elapsed: 17.08 seconds
# Inner - 8 of 12(generate other) -> time elapsed: 18.12 seconds
# Inner - 8 of 13(generate other) -> time elapsed: 19.15 seconds
# Inner - 8 of 14(generate other) -> time elapsed: 20.22 seconds
# Inner - 8 of 15(generate other day) -> time elapsed: 22.21 seconds
# Inner - 8 of 16(generate other day) -> time elapsed: 24.14 seconds
# Inner - 8 of 17(generate other day) -> time elapsed: 26.08 seconds
# Inner - 8 of 18(generate other day) -> time elapsed: 28.04 seconds
# Inner - 8 of 19(generate other day) -> time elapsed: 30.01 seconds
# Inner - 8 of 20(generate other day) -> time elapsed: 31.97 seconds
# Inner - 8 of 21(generate not buy) -> time elapsed: 34.56 seconds
# Inner - 8 of 22(handle na problem) -> time elapsed: 34.58 seconds
# Inner - 8 of 23(transform date type) -> time elapsed: 34.78 seconds
# Inner - 8 of 24(transform bool type) -> time elapsed: 34.8 seconds
# Stage - 8 of 4(generate) -> time elapsed: 5063.19 seconds
# Stage - 8 of 5(ouput) -> time elapsed: 5063.5 seconds
#
# Stage - 9 of 1(start) -> time elapsed: 5063.5 seconds
