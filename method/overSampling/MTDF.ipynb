# %% [markdown]
# # Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
dirThis = '/content/drive/MyDrive/1經濟學/專題/featureNew/'

train = pd.read_csv(dirThis + 'trainEncode.csv')
# test = pd.read_csv(dirThis + 'testEncodeBIG.csv')
y = pd.read_csv(dirThis + 'targetEncode.csv')

train_X = pd.merge(train, y, on = 'id')

# !pip install crucio

from crucio import MTDF, SMOTE 
method = MTDF()

t = train_X.drop(columns = ['offerdate', 'Unnamed: 0_x', 'Unnamed: 0_y'])
trainN = method.balance(t, 'repeater')
trainN.to_csv(dirThis + 'trainMTDF.csv')
